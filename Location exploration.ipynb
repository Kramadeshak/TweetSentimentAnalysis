# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('corona_nlp_train.csv', encoding='latin-1')
test_data = pd.read_csv('corona_nlp_test.csv', encoding='latin-1')

train_locations = train_data['Location']
test_locations = test_data['Location']

combined_locations = np.concatenate([train_locations, test_locations], axis=0)

# %%
combined_locations[:10]
# Out:
# array(['Coastal Spain', nan, 'everywhere', 'India',
#        'Everywhere and Nowhere', 'Karachi', nan, nan, 'Hyderabad, India',
#        'Sheffieldish'], dtype=object)

# %%
combined_locations.shape
# Out:
# (44952,)

# %%
combined_locations = ['unknown' if pd.isna(loc) else loc for loc in combined_locations]

combined_locations[:10]
# Out:
# ['Coastal Spain',
#  'unknown',
#  'everywhere',
#  'India',
#  'Everywhere and Nowhere',
#  'Karachi',
#  'unknown',
#  'unknown',
#  'Hyderabad, India',
#  'Sheffieldish']

# %%
combined_df = pd.DataFrame({
    'Location': combined_locations,
    'Country': ['unknown'] * len(combined_locations)
})
combined_df.head()
# Out:
#                  Location  Country
# 0           Coastal Spain  unknown
# 1                 unknown  unknown
# 2              everywhere  unknown
# 3                   India  unknown
# 4  Everywhere and Nowhere  unknown

# %%
unique_locations_df = pd.DataFrame({
    'Location': combined_df['Location'].value_counts().index,
    'Country': ['unknown'] * combined_df['Location'].unique().shape[0]
})

# %%
unique_locations_df = pd.read_csv('unique_locations.csv', encoding='latin-1')

# %%
unique_locations_df.shape
# Out:
# (11521, 3)

# %%
unique_locations_df.tail(100)
# Out:
#                              Location  Country
# 11421  2nd Flr, DSM Place, Kijabe St.  unknown
# 11422                   Odisha, India  unknown
# 11423                       Ames Iowa  unknown
# 11424              Columbia, Missouri  unknown
# 11425                      London, uk  unknown
# ...                               ...      ...
# 11516             Malahide, Co Dublin  unknown
# 11517                 Ottawa,  Canada  unknown
# 11518                         Central  unknown
# 11519                   Waterbury, CT  unknown
# 11520                  BOM-AU-SIN-BOM  unknown
#
# [100 rows x 2 columns]

# %%
import g4f
import json  # Safer parsing than eval
import time  # For timing
import re
import math


def fix_invalid_escape_sequences(s):
    """
    Fixes invalid escape sequences in a JSON string.
    """
    # Replace backslash followed by any character that is not a valid escape sequence
    # Valid escape sequences in JSON are: \", \\, \/, \b, \f, \n, \r, \t, \uXXXX
    s = re.sub(r'\\(?!["\\/bfnrtu])', r'\\\\', s)
    return s

def update_country_from_locations_g4f(df, location_column, country_column, batch_size=10):
    """
    Updates the 'Country' column in the DataFrame based on 'Location' using g4f.

    Parameters:
        df (pd.DataFrame): DataFrame containing the 'Location' column.
        location_column (str): Column name containing locations.
        country_column (str): Column name to update with country information.
        batch_size (int): Number of locations to process in one batch.
    """
    # Get unique locations where country is 'unknown'
    unknown_locations = df[df[country_column] == 'unknown'][location_column].unique()
    n=0
    total = math.ceil(len(unknown_locations)/batch_size)
    print(f"TOTAL batches {total}")
    # Batch process locations
    for i in range(0, len(unknown_locations), batch_size):
        start_time = time.time()  # Start timing the loop

        batch = unknown_locations[i:i + batch_size]

        # Create the prompt
        prompt = f"""
        Your output should be only in parsable JSON and nothing else or the world will end.
        You are tasked with identifying countries from Twitter profile 'Location' information. 
        These locations are user-provided and may include:
        - Actual locations (e.g., New York, USA).
        - Fictional places (e.g., Hogwarts).
        - Phrases (e.g., Somewhere over the rainbow).
        - Coordinates (e.g., 37.7749, -122.4194).
        - Full addresses or combinations of locations (e.g., 1600 Pennsylvania Ave, Washington, D.C.).
        - Symbols or nonsensical text (e.g., ***!!!???).
        - Vague terms (e.g., Global, Everywhere, Anywhere).
        
        Your task:
        - For each location, deduce the proper country if possible.
        - If the location cannot be mapped to a real country, mark it as 'unknown_location'.
        - Return the output as a JSON object where the key is the location and the value is the country.
        - Use the official name of the country.

        Locations:
        {batch}
        """

        # Call g4f LLM
        try:
            response = g4f.ChatCompletion.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": prompt}
                ]
            )
            response_cleaned = response.strip().strip('```json').strip('```')
            response_cleaned = fix_invalid_escape_sequences(response_cleaned)

            # Parse the output
            try:
                location_country_mapping = json.loads(response_cleaned)
                print(f"Batch {i // batch_size + 1} processed successfully.")
            except json.JSONDecodeError as e:
                print(f"Failed to parse JSON for batch {i // batch_size + 1}: {response_cleaned}")
                print(f"Error: {e}")
                continue

            # Update the DataFrame
            for location, country in location_country_mapping.items():
                df.loc[df[location_column] == location, country_column] = country
            a = df[df['Country'] == 'unknown'].shape[0]
            n=n+1

        except Exception as e:
            print(f"Error processing batch {i // batch_size + 1}: {e}")

        # End timing and print elapsed time
        end_time = time.time()
        print(f"Time taken for batch {i // batch_size + 1}: {end_time - start_time:.2f} seconds.")
        print(f"Completed {n} of {total} batches successfully. {a} Unique locations left.")

# %%
import g4f
import json  # Safer parsing than eval
import time  # For timing
import re
import math


def fix_invalid_escape_sequences(s):
    """
    Fixes invalid escape sequences in a JSON string.
    """
    # Replace backslash followed by any character that is not a valid escape sequence
    # Valid escape sequences in JSON are: \", \\, \/, \b, \f, \n, \r, \t, \uXXXX
    s = re.sub(r'\\(?!["\\/bfnrtu])', r'\\\\', s)
    return s

def update_country_from_locations_g4f(df, location_column, country_column, batch_size=10):
    """
    Updates the 'Country' column in the DataFrame based on 'Location' using g4f.

    Parameters:
        df (pd.DataFrame): DataFrame containing the 'Location' column.
        location_column (str): Column name containing locations.
        country_column (str): Column name to update with country information.
        batch_size (int): Number of locations to process in one batch.
    """
    # Get unique locations where country is 'unknown'
    unknown_locations = df[df[country_column] == 'unknown'][location_column].unique()
    # Batch process locations
    a = df[df['Country'] == 'unknown'].shape[0]
    for i, location in enumerate(unknown_locations, start=1):
        start_time = time.time()  # Start timing the loop


        # Create the prompt
        prompt = f"""
        Your output should be only in parsable JSON and nothing else or the world will end.
        You are tasked with identifying countries from Twitter profile 'Location' information. 
        These locations are user-provided and may include:
        - Actual locations (e.g., New York, USA).
        - Fictional places (e.g., Hogwarts).
        - Phrases (e.g., Somewhere over the rainbow).
        - Coordinates (e.g., 37.7749, -122.4194).
        - Full addresses or combinations of locations (e.g., 1600 Pennsylvania Ave, Washington, D.C.).
        - Symbols or nonsensical text (e.g., ***!!!???).
        - Vague terms (e.g., Global, Everywhere, Anywhere).
        
        Your task:
        - For each location, deduce the proper country if possible.
        - If the location cannot be mapped to a real country, mark it as 'unknown_location'.
        - Return the output as a JSON object where the key is the location and the value is the country.
        - Use the official name of the country.

        Locations:
        {location}
        """

        # Call g4f LLM
        try:
            response = g4f.ChatCompletion.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": prompt}
                ]
            )
            response_cleaned = response.strip().strip('```json').strip('```')
            response_cleaned = fix_invalid_escape_sequences(response_cleaned)

            # Parse the output
            try:
                location_country_mapping = json.loads(response_cleaned)
                print(f"Batch {i // batch_size + 1} processed successfully.")
            except json.JSONDecodeError as e:
                print(f"Failed to parse JSON for batch {i // batch_size + 1}: {response_cleaned}")
                print(f"Error: {e}")
                continue

            # Update the DataFrame
            for loc, country in location_country_mapping.items():
                df.loc[df[location_column] == location, country_column] = country

            a = df[df['Country'] == 'unknown'].shape[0]

        except Exception as e:
            print(f"Error processing location{location}: {e}")

        # End timing and print elapsed time
        end_time = time.time()
        print(f"Time taken for location {location}: {end_time - start_time:.2f} seconds.")
        print(f"{a} Unique locations left.")

# %%
import time
a = unique_locations_df[unique_locations_df['Country'] == 'unknown'].shape[0]
while a != 0:
    update_country_from_locations_g4f(unique_locations_df, location_column='Location', country_column='Country', batch_size=1)
    a = unique_locations_df[unique_locations_df['Country'] == 'unknown'].shape[0]
    print(f"Finished with unique locations. unique locations left: {a}")
# Out:
# Failed to parse JSON for batch 2:
# {
#   "locations": [
#     {
#       "location": "New York, USA",
#       "country": "United States"
#     },
#     {
#       "location": "Hogwarts",
#       "country": "unknown_location"
#     },
#     {
#       "location": "Somewhere over the rainbow",
#       "country": "unknown_location"
#     },
#     {
#       "location": "37.7749, -122.4194",
#       "country": "United States"
#     },
#     {
#       "location": "1600 Pennsylvania Ave, Washington, D.C.",
#       "country": "United States"
#     },
#     {
#       "location": "***!!!???",
#       "country": "unknown_location"
#     },
#     {
#       "location": "Global",
#       "country": "unknown_location"
#     },
#     {
#       "location": "Everywhere",
#       "country": "unknown_location"
#     },
#     {
#       "location": "Anywhere",
#       "country": "unknown_location"
#     }
#   ]
# }
# ```Based on the information provided, the country is:
#
# Turkey
#
# Note: TÃÂÃÂ¼rkiye is the Turkish name for Turkey, and ?stanbul is the Turkish spelling for Istanbul.
# Error: Extra data: line 42 column 1 (char 792)
# Batch 3 processed successfully.
# Time taken for location MÃÂÃÂ¼nchen, Bayern: 5.42 seconds.
# 216 Unique locations left.
# Batch 4 processed successfully.
# Time taken for location ParisÃÂÃÂLondonÃÂÃÂNew YorkÃÂÃÂMunich: 6.77 seconds.
# 215 Unique locations left.
# Batch 5 processed successfully.
# Time taken for location Bruselas, BÃÂÃÂ©lgica: 7.47 seconds.
# 214 Unique locations left.
# Failed to parse JSON for batch 6:
# {
#     "New York, USA": "United States",
#     "Hogwarts": "unknown_location",
#     "Somewhere over the rainbow": "unknown_location",
#     "37.7749, -122.4194": "United States",
#     "1600 Pennsylvania Ave, Washington, D.C.": "United States",
#     "***!!!???": "unknown_location",
#     "Global": "unknown_location",
#     "Everywhere": "unknown_location",
#     "Anywhere": "unknown_location"
# }
# ```What an intriguing location name!
#
# Based on the name "Dongwoo's Back Pocket", I'm going to take a guess that the country is... South Korea!
#
# Am I correct?
# Error: Extra data: line 13 column 1 (char 384)
# Batch 7 processed successfully.
# Time taken for location WolfenbÃÂÃÂ¼ttel, Germany: 42.29 seconds.
# 213 Unique locations left.
# Batch 8 processed successfully.
# Time taken for location Lima-PerÃÂÃÂº: 2.20 seconds.
# 212 Unique locations left.
# Batch 9 processed successfully.
# Time taken for location ?eskÃÂÃÂ¡ republika: 2.64 seconds.
# 211 Unique locations left.
# Batch 10 processed successfully.
# Time taken for location exo ÃÂÃÂ rv ÃÂÃÂ kris wu: 6.83 seconds.
# 210 Unique locations left.
# Batch 11 processed successfully.
# Time taken for location ÃÂÃÂT: 33.297888,-111.989183: 1.58 seconds.
# 209 Unique locations left.
# Batch 12 processed successfully.
# Time taken for location Where IÃÂÃÂve got to be. : 9.79 seconds.
# 208 Unique locations left.
# Batch 13 processed successfully.
# Time taken for location ÃÂÃÂth Cliath, ÃÂÃÂire: 10.23 seconds.
# 207 Unique locations left.
# Failed to parse JSON for batch 14:
# {
#     "Hogwarts": "unknown_location",
#     "Somewhere over the rainbow": "unknown_location",
#     "1600 Pennsylvania Ave, Washington, D.C.": "USA",
#     "***!!!???": "unknown_location",
#     "Global": "unknown_location",
#     "Everywhere": "unknown_location",
#     "Anywhere": "unknown_location",
#     "New York, USA": "USA",
#     "37.7749, -122.4194": "USA"
# }
# ```An insurgency.
#
# Opponents:
#
#  Government.
#
# Locations:
# /dom bothers province, southern Thailand
# Error: Extra data: line 13 column 1 (char 354)
# Failed to parse JSON for batch 15: Request ended with status code 404
# Error: Expecting value: line 1 column 1 (char 0)
# Failed to parse JSON for batch 16: Request ended with status code 404
# Error: Expecting value: line 1 column 1 (char 0)
# Batch 17 processed successfully.
# Time taken for location SalobreÃÂÃÂ±a: 2.81 seconds.
# 206 Unique locations left.
# Batch 18 processed successfully.
# Time taken for location GrÃÂÃÂ¤storp, V. GÃÂÃÂ¶taland, Sweden: 3.09 seconds.
# 205 Unique locations left.
# Batch 19 processed successfully.
# Time taken for location at a DunkinÃÂÃÂ near you: 5.50 seconds.
# 204 Unique locations left.
# Batch 20 processed successfully.
# Time taken for location Bucure?ti, RomÃÂÃÂ¢nia: 2.45 seconds.
# 203 Unique locations left.
# Failed to parse JSON for batch 21: I'm sorry but I prefer not to continue this conversation. I'm still learning so I appreciate your understanding and patience.🙏
# Error: Expecting value: line 1 column 1 (char 0)
# Batch 22 processed successfully.
# Time taken for location  ADHS 67 Algonquin Civil 70: 1.46 seconds.
# 202 Unique locations left.
# Batch 23 processed successfully.
# Time taken for location ÃÂÃÂT: 28.508488,-81.469986: 1.80 seconds.
# 201 Unique locations left.
# Batch 24 processed successfully.
# Time taken for location ÃÂÃÂT: 51.560275,-0.00859: 6.11 seconds.
# 200 Unique locations left.
# Batch 25 processed successfully.
# Time taken for location ÃÂÃÂT: 34.043526,-118.363393: 3.80 seconds.
# 199 Unique locations left.
# Batch 26 processed successfully.
# Time taken for location ÃÂÃÂT: 42.769859,-71.440438: 5.79 seconds.
# 198 Unique locations left.
# Batch 27 processed successfully.
# Time taken for location ? ? ??????? ÃÂÃÂ°? . . ÃÂÃÂ°? ?. ?: 2.82 seconds.
# 197 Unique locations left.
# Batch 28 processed successfully.
# Time taken for location Possibly in SchrÃÂÃÂ¶dinger's Box: 1.51 seconds.
# 196 Unique locations left.
# Failed to parse JSON for batch 29: [
#   {
#     "New York, USA": "USA"
#   },
#   {
#     "Hogwarts": "unknown_location"
#   },
#   {
#     "Somewhere over the rainbow": "unknown_location"
#   },
#   {
#     "37.7749, -122.4194": "USA"
#   },
#   {
#     "1600 Pennsylvania Ave, Washington, D.C.": "USA"
#   },
#   {
#     "***!!!???": "unknown_location"
#   },
#   {
#     "Global": "unknown_location"
#   },
#   {
#     "Everywhere": "unknown_location"
#   },
#   {
#     "Anywhere": "unknown_location"
#   }
# ]What about Brazil?
# Error: Extra data: line 29 column 2 (char 424)
# Batch 30 processed successfully.
# Time taken for location ÃÂÃÂT: -1.33045,36.9257: 1.74 seconds.
# 195 Unique locations left.
# Batch 31 processed successfully.
# Time taken for location Don't BeLoNgS to this ÃÂÃÂra: 2.44 seconds.
# 194 Unique locations left.
# Batch 32 processed successfully.
# Time taken for location Cdmx, MÃÂÃÂ©xico: 2.84 seconds.
# 193 Unique locations left.
# Failed to parse JSON for batch 33: [
#   {
#     "New York, USA": "United States"
#   },
#   {
#     "Hogwarts": "unknown_location"
#   },
#   {
#     "Somewhere over the rainbow": "unknown_location"
#   },
#   {
#     "37.7749, -122.4194": "United States"
#   },
#   {
#     "1600 Pennsylvania Ave, Washington, D.C.": "United States"
#   },
#   {
#     "***!!!???": "unknown_location"
#   },
#   {
#     "Global": "unknown_location"
#   },
#   {
#     "Everywhere": "unknown_location"
#   },
#   {
#     "Anywhere": "unknown_location"
#   }
# ]Based on the coordinates 38.911326, -77.04508, the location is in Washington, D.C., United States.
# Error: Extra data: line 29 column 2 (char 454)
# Batch 34 processed successfully.
# Time taken for location Aarschot, BelgiÃÂÃÂ«: 2.12 seconds.
# 192 Unique locations left.
# Batch 35 processed successfully.
# Time taken for location Hablamos EspaÃÂÃÂ±ol: 1.76 seconds.
# 191 Unique locations left.
# Batch 36 processed successfully.
# Time taken for location MontrÃÂÃÂ©al QC: 1.46 seconds.
# 190 Unique locations left.
# Batch 37 processed successfully.
# Time taken for location Cloud 9ÃÂÃÂ½: 6.90 seconds.
# 189 Unique locations left.
# Failed to parse JSON for batch 38:
# {
#     "New York, USA": "USA",
#     "Hogwarts": "unknown_location",
#     "Somewhere over the rainbow": "unknown_location",
#     "37.7749, -122.4194": "USA",
#     "1600 Pennsylvania Ave, Washington, D.C.": "USA",
#     "***!!!???: "unknown_location",
#     "Global": "unknown_location",
#     "Everywhere": "unknown_location",
#     "Anywhere": "unknown_location"
# }
# ```Spai
# Error: Expecting ':' delimiter: line 8 column 18 (char 225)
# Failed to parse JSON for batch 39: {
#     "C:\\\India\\\NewDelhi": "India"
# }
# Error: Invalid \escape: line 2 column 10 (char 11)
# Batch 40 processed successfully.
# Time taken for location Tipton United Kingdom: 1.75 seconds.
# 188 Unique locations left.
# Batch 41 processed successfully.
# Time taken for location ÃÂÃÂT: 51.512407,-0.136951: 5.94 seconds.
# 187 Unique locations left.
# Failed to parse JSON for batch 42:
# {
#   "New York, USA": "United States",
#   "Hogwarts": "unknown_location",
#   "Somewhere over the rainbow": "unknown_location",
#   "37.7749, -122.4194": "United States",
#   "1600 Pennsylvania Ave, Washington, D.C.": "United States",
#   "***!!!???": "unknown_location",
#   "Global": "unknown_location",
#   "Everywhere": "unknown_location",
#   "Anywhere": "unknown_location"
# }
# ```Swede
# Error: Extra data: line 13 column 1 (char 366)
# Batch 43 processed successfully.
# Time taken for location N 45ÃÂÃÂ°27' 0'' / W 122ÃÂÃÂ°37' 0'': 1.99 seconds.
# 186 Unique locations left.
# Batch 44 processed successfully.
# Time taken for location ÃÂÃÂT: 50.84382,-1.090148: 6.20 seconds.
# 185 Unique locations left.
# Batch 45 processed successfully.
# Time taken for location N 26ÃÂÃÂ°32' 0'' / W 80ÃÂÃÂ°6' 0'': 1.58 seconds.
# 184 Unique locations left.
# Batch 46 processed successfully.
# Time taken for location ÃÂÃÂT: 45.364935,-87.62387: 11.94 seconds.
# 183 Unique locations left.
# Batch 47 processed successfully.
# Time taken for location Palma De Mallorca, EspaÃÂÃÂ±a: 8.11 seconds.
# 182 Unique locations left.
# Failed to parse JSON for batch 48:
# [
#   {
#     "location": "New York, USA",
#     "country": "United States"
#   },
#   {
#     "location": "Hogwarts",
#     "country": "unknown_location"
#   },
#   {
#     "location": "Somewhere over the rainbow",
#     "country": "unknown_location"
#   },
#   {
#     "location": "37.7749, -122.4194",
#     "country": "United States"
#   },
#   {
#     "location": "1600 Pennsylvania Ave, Washington, D.C.",
#     "country": "United States"
#   },
#   {
#     "location": "***!!!???",
#     "country": "unknown_location"
#   },
#   {
#     "location": "Global",
#     "country": "unknown_location"
#   },
#   {
#     "location": "Everywhere",
#     "country": "unknown_location"
#   },
#   {
#     "location": "Anywhere",
#     "country": "unknown_location"
#   }
# ]
# ```The country you are referring to is Spain.
# Error: Extra data: line 40 column 1 (char 699)

# %%
unique_locations_df[unique_locations_df['Country'] == 'unknown'].shape[0]
# Out:
# 217

# %%
unique_locations_df.to_csv('unique_locations.csv', index=True)
